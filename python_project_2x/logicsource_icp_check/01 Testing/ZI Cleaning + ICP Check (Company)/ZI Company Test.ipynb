# %%
import sys

sys.path.insert(0, r"C:\Users\WeiZhenLim\OneDrive - 2X LLC\Work\Python\LS_ZI_Cleaning_ICP_Check")

from LS_ICP_ZI import zi_icp_check
import pandas as pd

# %%
# Read CSV
df = pd.read_csv("Test.csv")
df.head()
# Out:
#    ZoomInfo Company ID                Company Name                Website  \
# 0              1475361              Amazon.com Inc         www.amazon.com
# 1            155353090                 Walmart Inc  corporate.walmart.com
# 2            345283492       Costco Wholesale Corp         www.costco.com
# 3             37536530                 Target Corp         www.target.com
# 4              8590337  Marriott International Inc       www.marriott.com
#
#    Founded Year Company HQ Phone             Fax        Ticker  \
# 0        1994.0   (206) 266-1000  (206) 622-2405  NASDAQ: AMZN
# 1        1962.0   (479) 273-4000  (479) 277-1830     NYSE: WMT
# 2        1976.0   (425) 313-8100  (425) 313-8103  NASDAQ: COST
# 3        1902.0   (612) 304-6073             NaN     NYSE: TGT
# 4        1927.0   (301) 380-3000  (925) 934-6374   NASDAQ: MAR
#
#    Revenue (in 000s USD) Revenue Range (in USD)  Employees  ...  \
# 0              538046000           Over $5 bil.    1541000  ...
# ...

# %%
df_checked = zi_icp_check(df, "Test.csv", False)

df_checked.to_csv("Test_Output V3.csv", index=False)
# Out:
# Check for the following:
# 1. Input data (file) matches with the 'is_company` parameter. If `is_company` = True (By default is True), input data = ZI Company Data; If `is_company` = False, input data = ZI Contact Data
# 2. There is a change in the column names from the ZI Company/Contact Data.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\WeiZhenLim\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...
