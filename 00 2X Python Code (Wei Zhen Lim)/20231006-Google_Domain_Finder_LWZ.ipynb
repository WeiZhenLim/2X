# %% [markdown]
# Last Update: 6th October 2023
#
# Status: No pending updates, ready to use
#
# ---

# %% [markdown]
# #### 1. Import Library (Required Library Installation If Module Not Found)

# %%
from googlesearch import search
import pandas as pd
import tldextract

# %% [markdown]
# #### 2. Read CSV (Suggesting to convert file to CSV UTF-8 for better performance)
#
# <u>Read Me Before Start Scraping</u>
# 1. To avoid any filepath issue, it is best to keep this "ipynb" file with the Excel file that you wish to read in the same folder.
# 2. This Python script only supports CSV file, convert the Excel file into CSV UTF-8.
# 1. Ensure that the list of companies do not have any duplicates. **[REMOVE DUPLICATES]**
# 2. Check whether companies with empty website has any previous record in the dataset. If yes, please fill it in with the existing data in the dataset.
#
#     However, do take note that each company should have only one website as there might be chances of one company having multiple website in the dataset due to technical issues or human errors. **[CLEAN THE DATASET FIRST BEFORE SCRAPING]**
#
# 3. Only include the companies with no website for the web scraping to save time. **[INCLUDE ONLY COMPANY WITH BLANK WEBSITE]**

# %%
# update the filename
excel_file = "Test_Google_Domain_Finder" 

df = pd.read_csv(excel_file + ".csv")
df = df['Company_Name']
df
# Out:
# 0         The TJX Companies, Inc.
# 1       BJ's Wholesale Club, Inc.
# 2                      Fred Meyer
# 3           ADT Security Services
# 4                  Pier 1 Imports
# 5                            LCBO
# 6                    Michael Kors
# 7           ToysÃ¢â‚¬Å“RÃ¢â‚¬ÂUs
# 8             Lululemon Athletica
# 9                     Lucky Brand
# 10                         Fossil
# 11          ACC Facility Services
# 12                      Barcoding
# 13                         Conn's
# 14                   ProShip, Inc
# 15                 Shamrock Foods
# 16                        L'oreal
# 17                      Cosy Robo
# 18                       Coborn's
# 19                        ALANTRA
# 20                  buchheits.com
# 21       Alimentation Couche-Tard
# 22               American Freight
# 23                 channeladvisor
# 24                  Anthropologie
# 25                  Champs Sports
# 26                  Walmart, Inc.
# 27                  Neiman Marcus
# 28                     Tory Burch
# 29              Roots Corporation
# 30                    Arhaus, LLC
# 31                            MEC
# 32                      Dillard's
# 33                   Sur La Table
# 34                      UT Austin
# 35                        Aritzia
# 36             Hobby Lobby Stores
# 37    Ashley Furniture Industries
# 38                         Stores
# 39           Jockey International
# 40                   BLAIN SUPPLY
# 41                          Bcldb
# 42                     CVS Health
# 43                      Indochino
# 44        Kohls Department Stores
# 45              Daniel's Jewelers
# 46     Roundy's Supermarkets Inc.
# 47       Pilot Travel Centers LLC
# 48        K-VA-T Food Stores Inc.
# 49                       Kum & Go
# Name: Company_Name, dtype: object

# %% [markdown]
# #### 3. Get URL

# %%
domains = []

GoodConnection = True
start = 0

while GoodConnection:
    try:
        for i in range(start, len(df)):
            for url in search(df[i], stop=1):
                domains.append(url)
                if not len(domains) == i+1:
                    domains.append('-')
                print(f'Exporting Company no {i+1}: {df[i]}')
    except:
        print(f'Fail to export company no {i+1}: {df[i]}. Try Again')
        start = i
        continue
    else:
        break #Exit loop if no error occurred

print(f'Scraping complete, {i+1} out of {df.shape[0]} domain being extracted. {"OK" if i+1 == df.shape[0] else "NOT OK"}')
# Out:
# Exporting Company no 1: The TJX Companies, Inc.
# Exporting Company no 2: BJ's Wholesale Club, Inc.
# Exporting Company no 3: Fred Meyer
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Fail to export company no 4: ADT Security Services. Try Again
# Exporting Company no 4: ADT Security Services
# Exporting Company no 5: Pier 1 Imports
# Exporting Company no 6: LCBO
# Exporting Company no 7: Michael Kors
# Exporting Company no 8: ToysÃ¢â‚¬Å“RÃ¢â‚¬ÂUs
# Exporting Company no 9: Lululemon Athletica
# Fail to export company no 10: Lucky Brand. Try Again
# Exporting Company no 10: Lucky Brand
# Exporting Company no 11: Fossil
# Exporting Company no 12: ACC Facility Services
# Exporting Company no 13: Barcoding
# Exporting Company no 14: Conn's
# Exporting Company no 15: ProShip, Inc
# Exporting Company no 16: Shamrock Foods
# Exporting Company no 17: L'oreal
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Fail to export company no 18: Cosy Robo. Try Again
# Exporting Company no 18: Cosy Robo
# Exporting Company no 19: Coborn's
# Exporting Company no 20: ALANTRA
# Exporting Company no 21: buchheits.com
# Fail to export company no 22: Alimentation Couche-Tard. Try Again
# Exporting Company no 22: Alimentation Couche-Tard
# Exporting Company no 23: American Freight
# Exporting Company no 24: channeladvisor
# Exporting Company no 25: Anthropologie
# Exporting Company no 26: Champs Sports
# Exporting Company no 27: Walmart, Inc.
# Exporting Company no 28: Neiman Marcus
# Exporting Company no 29: Tory Burch
# Exporting Company no 30: Roots Corporation
# Exporting Company no 31: Arhaus, LLC
# Exporting Company no 32: MEC
# Exporting Company no 33: Dillard's
# Exporting Company no 34: Sur La Table
# Exporting Company no 35: UT Austin
# Exporting Company no 36: Aritzia
# Exporting Company no 37: Hobby Lobby Stores
# Exporting Company no 38: Ashley Furniture Industries
# Exporting Company no 39: Stores
# Exporting Company no 40: Jockey International
# Exporting Company no 41: BLAIN SUPPLY
# Exporting Company no 42: Bcldb
# Exporting Company no 43: CVS Health
# Exporting Company no 44: Indochino
# Exporting Company no 45: Kohls Department Stores
# Exporting Company no 46: Daniel's Jewelers
# Exporting Company no 47: Roundy's Supermarkets Inc.
# Exporting Company no 48: Pilot Travel Centers LLC
# Exporting Company no 49: K-VA-T Food Stores Inc.
# Exporting Company no 50: Kum & Go
# Scraping complete, 50 out of 50 domain being extracted. OK

# %% [markdown]
# #### Previous Script (BackUp)

# %%
# domains = []

# for i in range(0, len(df)):
#     for url in search(df[i], stop=1):
#         domains.append(url)
#         if not len(domains) == i+1:
#             domains.append('-')
#         print(f'Exporting Company no {i+1}: {df[i]}')

# print(f'Scraping complete, {i+1} out of {df.shape[0]} domain being extracted. {"OK" if i+1 == df.shape[0] else "NOT OK"}')

# %% [markdown]
# #### 4. Save results as Dataframe

# %%
data = []
data = pd.DataFrame(columns=['Company Name', 'URL'])
data['Company Name'] = df
data['URL'] = domains
data
# Out:
#                    Company Name  \
# 0       The TJX Companies, Inc.
# 1     BJ's Wholesale Club, Inc.
# 2                    Fred Meyer
# 3         ADT Security Services
# 4                Pier 1 Imports
# 5                          LCBO
# 6                  Michael Kors
# 7         ToysÃ¢â‚¬Å“RÃ¢â‚¬ÂUs
# 8           Lululemon Athletica
# 9                   Lucky Brand
# 10                       Fossil
# 11        ACC Facility Services
# 12                    Barcoding
# 13                       Conn's
# 14                 ProShip, Inc
# 15               Shamrock Foods
# 16                      L'oreal
# 17                    Cosy Robo
# 18                     Coborn's
# 19                      ALANTRA
# 20                buchheits.com
# 21     Alimentation Couche-Tard
# 22             American Freight
# 23               channeladvisor
# 24                Anthropologie
# 25                Champs Sports
# 26                Walmart, Inc.
# 27                Neiman Marcus
# 28                   Tory Burch
# 29            Roots Corporation
# 30                  Arhaus, LLC
# 31                          MEC
# 32                    Dillard's
# 33                 Sur La Table
# 34                    UT Austin
# 35                      Aritzia
# 36           Hobby Lobby Stores
# 37  Ashley Furniture Industries
# 38                       Stores
# 39         Jockey International
# 40                 BLAIN SUPPLY
# 41                        Bcldb
# 42                   CVS Health
# 43                    Indochino
# 44      Kohls Department Stores
# 45            Daniel's Jewelers
# 46   Roundy's Supermarkets Inc.
# 47     Pilot Travel Centers LLC
# 48      K-VA-T Food Stores Inc.
# 49                     Kum & Go
#
#                                                   URL
# 0                                https://www.tjx.com/
# 1                                https://www.bjs.com/
# 2                          https://www.fredmeyer.com/
# 3                                https://www.adt.com/
# 4                              https://www.pier1.com/
# 5                               https://www.lcbo.com/
# 6                        https://www.michaelkors.com/
# 7   https://stackoverflow.com/questions/31671906/h...
# 8                         https://shop.lululemon.com/
# 9                         https://www.luckybrand.com/
# 10                              https://fossilmy.com/
# 11  https://my.linkedin.com/company/acc-facility-s...
# 12                         https://www.barcoding.com/
# 13                             https://www.conns.com/
# 14                            https://proshipinc.com/
# 15               https://www.shamrockfoodservice.com/
# 16                         https://www.loreal.com/en/
# 17                              https://cosyrobo.com/
# 18                           https://www.coborns.com/
# 19                           https://www.alantra.com/
# 20                         https://www.buchheits.com/
# 21                       https://www.couche-tard.com/
# 22                   https://www.americanfreight.com/
# 23                    https://www.channeladvisor.com/
# 24                     https://www.anthropologie.com/
# 25                      https://www.champssports.com/
# 26                     https://corporate.walmart.com/
# 27                      https://www.neimanmarcus.com/
# 28                   https://www.toryburch.com/en-us/
# 29                             https://www.roots.com/
# 30                            https://www.arhaus.com/
# 31                         https://www.mpm.edu.my/en/
# 32                          https://www.dillards.com/
# 33                        https://www.surlatable.com/
# 34                            https://www.utexas.edu/
# 35                           https://www.aritzia.com/
# 36                        https://www.hobbylobby.com/
# 37                   https://www.ashleyfurniture.com/
# 38  https://www.tripadvisor.com.my/Attractions-g29...
# 39                            https://www.jockey.com/
# 40                      https://www.farmandfleet.com/
# 41                             https://www.bcldb.com/
# 42                         https://www.cvshealth.com/
# 43                         https://www.indochino.com/
# 44                             https://www.kohls.com/
# 45                   https://www.danielsjewelers.com/
# 46                           https://www.roundys.com/
# 47                           http://pilotflyingj.com/
# 48          https://www.foodcity.com/content/aboutus/
# 49                          https://www.kumandgo.com/

# %% [markdown]
# #### 5. Extract company domain
#
# Reference: https://www.askpython.com/python/examples/extract-domain-name-from-url

# %%
data["Subdomain"] = data["URL"].apply(lambda x : tldextract.extract(x).subdomain)
data["Domain"] = data["URL"].apply(lambda x : tldextract.extract(x).domain)
data["Suffix"] = data["URL"].apply(lambda x : tldextract.extract(x).suffix)

# %% [markdown]
# #### 6. Label invalid domain such as stackoverflow, facebook, twitter, linkedin, wikipedia.

# %%
invalid_domain = ["stackoverflow", "facebook", "twitter", "linkedin", "wikipedia"]

data["Common_Error"] = data["Domain"].apply(lambda x: 1 if x in invalid_domain else 0)

# %% [markdown]
# #### 6. Save to Excel

# %%
# update the filename
new_File = excel_file + "_Output"

writer = pd.ExcelWriter(new_File + ".xlsx")
data.to_excel(writer, index = None)
writer.close()
